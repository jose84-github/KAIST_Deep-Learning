# %% [markdown]
# #LeNet-1
#
# Using Improved basic CNN model, try to make LeNet-1 as below
#
# Name : 조성은
# Student ID : 20204150

# %%
# LeNet 1 만들기 - Basic Model
import tensorflow as tf
print(tf.__version__)
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images.reshape(60000, 28, 28, 1)
training_images=training_images / 255.0
test_images = test_images.reshape(10000, 28, 28, 1)
test_images=test_images/255.0
model = tf.keras.models.Sequential([
                                    
  tf.keras.layers.Conv2D(4, (5,5), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),

  tf.keras.layers.Conv2D(12, (5,5), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),

  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(16, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(training_images, training_labels, epochs=5)
test_loss = model.evaluate(test_images, test_labels)
# Out:
# 2.4.1
# Model: "sequential_91"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_519 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_505 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_520 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_506 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_92 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_183 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dense_184 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.9118 - accuracy: 0.6846
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4679 - accuracy: 0.8284
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4068 - accuracy: 0.8543
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3772 - accuracy: 0.8634
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3604 - accuracy: 0.8696
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3741 - accuracy: 0.8691

# %%
# LeNet 1 만들기 - Basic Model + Dropout 0.02
import tensorflow as tf
print(tf.__version__)
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images.reshape(60000, 28, 28, 1)
training_images=training_images / 255.0
test_images = test_images.reshape(10000, 28, 28, 1)
test_images=test_images/255.0
model = tf.keras.models.Sequential([
                                    
  tf.keras.layers.Conv2D(4, (5,5), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Dropout(rate = 0.02),

  tf.keras.layers.Conv2D(12, (5,5), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Dropout(rate = 0.02),

  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(16, activation='relu'),
  tf.keras.layers.Dropout(rate = 0.02),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(training_images, training_labels, epochs=5)
test_loss = model.evaluate(test_images, test_labels)
# Out:
# 2.4.1
# Model: "sequential_87"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_511 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_497 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_171 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_512 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_498 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_172 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_88 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_175 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_173 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_176 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 1.0601 - accuracy: 0.6211
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5467 - accuracy: 0.8037
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4738 - accuracy: 0.8291
# Epoch 4/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4358 - accuracy: 0.8409
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4098 - accuracy: 0.8511
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3841 - accuracy: 0.8615

# %%
# LeNet 1 만들기 - 2 Conv Layer + GridSearch
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
print(tf.__version__)
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images.reshape(60000, 28, 28, 1)
training_images=training_images / 255.0
test_images = test_images.reshape(10000, 28, 28, 1)
test_images=test_images/255.0

def build_LeNet(dropout_rate, epochs):
  model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(4, (5,5), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(rate = dropout_rate),

    tf.keras.layers.Conv2D(12, (5,5), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(rate = dropout_rate),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dropout(rate = dropout_rate),
    tf.keras.layers.Dense(10, activation='softmax')
  ])
  model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
  model.summary()
  #model.fit(training_images, training_labels, epochs=epochs)
  #test_loss, test_acc = model.evaluate(test_images, test_labels)
  #print("Test Accuracy is {}".format(test_acc))

  return model

model = tf.keras.wrappers.scikit_learn.KerasClassifier(build_fn = build_LeNet, verbose=0)

param_grid = {
    'batch_size':[10,20],
    'epochs':[10, 30],
    'dropout_rate':[0.05,0.1]
}

grid = GridSearchCV(estimator= model, param_grid=param_grid, cv=2)
grid = grid.fit(training_images, training_labels)
# Out:
# 2.4.1
# Model: "sequential_68"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_473 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_459 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_119 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_474 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_460 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_120 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_69 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_137 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_121 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_138 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_69"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_475 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_461 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_122 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_476 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_462 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_123 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_70 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_139 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_124 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_140 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_70"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_477 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_463 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_125 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_478 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_464 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_126 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_71 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_141 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_127 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_142 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_71"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_479 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_465 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_128 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_480 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_466 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_129 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_72 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_143 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_130 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_144 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_72"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_481 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_467 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_131 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_482 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_468 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_132 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_73 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_145 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_133 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_146 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_73"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_483 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_469 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_134 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_484 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_470 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_135 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_74 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_147 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_136 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_148 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_74"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_485 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_471 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_137 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_486 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_472 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_138 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_75 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_149 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_139 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_150 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_75"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_487 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_473 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_140 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_488 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_474 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_141 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_76 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_151 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_142 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_152 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_76"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_489 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_475 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_143 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_490 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_476 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_144 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_77 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_153 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_145 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_154 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_77"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_491 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_477 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_146 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_492 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_478 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_147 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_78 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_155 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_148 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_156 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_78"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_493 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_479 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_149 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_494 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_480 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_150 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_79 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_157 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_151 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_158 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_79"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_495 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_481 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_152 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_496 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_482 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_153 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_80 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_159 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_154 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_160 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_80"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_497 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_483 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_155 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_498 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_484 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_156 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_81 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_161 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_157 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_162 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_81"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_499 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_485 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_158 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_500 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_486 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_159 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_82 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_163 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_160 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_164 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_82"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_501 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_487 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_161 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_502 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_488 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_162 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_83 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_165 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_163 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_166 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_83"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_503 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_489 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_164 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_504 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_490 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_165 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_84 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_167 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_166 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_168 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_84"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_505 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_491 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_167 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_506 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_492 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_168 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_85 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_169 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_169 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_170 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Best Parameters are {'batch_size': 10, 'dropout_rate': 0.05, 'epochs': 30}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-979aa949e6c7> in <module>()
#      45
#      46 print("Best Parameters are {}".format(grid.best_params_))
# ---> 47 print("Best Score is {}".format(grid_search.best_score_))
#
# NameError: name 'grid_search' is not defined

# %%
print("Best Parameters are {}".format(grid.best_params_))
print("Best Score is {}".format(grid.best_score_))
# Out:
# Best Parameters are {'batch_size': 10, 'dropout_rate': 0.05, 'epochs': 30}
# Best Score is 0.8807666599750519

# %%
# LeNet 1 만들기 - Basic Model + Dropout 0.05 + Epochs 30
import tensorflow as tf
print(tf.__version__)
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images.reshape(60000, 28, 28, 1)
training_images=training_images / 255.0
test_images = test_images.reshape(10000, 28, 28, 1)
test_images=test_images/255.0
model = tf.keras.models.Sequential([
                                    
  tf.keras.layers.Conv2D(4, (5,5), activation='relu', input_shape=(28, 28, 1)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Dropout(rate = 0.05),

  tf.keras.layers.Conv2D(12, (5,5), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Dropout(rate = 0.05),

  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(16, activation='relu'),
  tf.keras.layers.Dropout(rate = 0.05),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(training_images, training_labels, epochs=30)
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(test_acc)
# Out:
# 2.4.1
# Model: "sequential_90"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_517 (Conv2D)          (None, 24, 24, 4)         104
# _________________________________________________________________
# max_pooling2d_503 (MaxPoolin (None, 12, 12, 4)         0
# _________________________________________________________________
# dropout_180 (Dropout)        (None, 12, 12, 4)         0
# _________________________________________________________________
# conv2d_518 (Conv2D)          (None, 8, 8, 12)          1212
# _________________________________________________________________
# max_pooling2d_504 (MaxPoolin (None, 4, 4, 12)          0
# _________________________________________________________________
# dropout_181 (Dropout)        (None, 4, 4, 12)          0
# _________________________________________________________________
# flatten_91 (Flatten)         (None, 192)               0
# _________________________________________________________________
# dense_181 (Dense)            (None, 16)                3088
# _________________________________________________________________
# dropout_182 (Dropout)        (None, 16)                0
# _________________________________________________________________
# dense_182 (Dense)            (None, 10)                170
# =================================================================
# Total params: 4,574
# Trainable params: 4,574
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 1.0469 - accuracy: 0.6253
# Epoch 2/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5511 - accuracy: 0.7952
# Epoch 3/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4833 - accuracy: 0.8226
# Epoch 4/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4400 - accuracy: 0.8387
# Epoch 5/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4172 - accuracy: 0.8494
# Epoch 6/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4032 - accuracy: 0.8521
# Epoch 7/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3864 - accuracy: 0.8591
# Epoch 8/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3844 - accuracy: 0.8572
# Epoch 9/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3726 - accuracy: 0.8627
# Epoch 10/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3733 - accuracy: 0.8597
# Epoch 11/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3633 - accuracy: 0.8646
# Epoch 12/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3558 - accuracy: 0.8664
# Epoch 13/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3526 - accuracy: 0.8674
# Epoch 14/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3509 - accuracy: 0.8700
# Epoch 15/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3464 - accuracy: 0.8714
# Epoch 16/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3453 - accuracy: 0.8727
# Epoch 17/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3420 - accuracy: 0.8719
# Epoch 18/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3425 - accuracy: 0.8720
# Epoch 19/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3352 - accuracy: 0.8760
# Epoch 20/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3414 - accuracy: 0.8734
# Epoch 21/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3353 - accuracy: 0.8766
# Epoch 22/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3298 - accuracy: 0.8765
# Epoch 23/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3285 - accuracy: 0.8770
# Epoch 24/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3240 - accuracy: 0.8784
# Epoch 25/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3256 - accuracy: 0.8781
# Epoch 26/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3256 - accuracy: 0.8793
# Epoch 27/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3195 - accuracy: 0.8807
# Epoch 28/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3182 - accuracy: 0.8840
# Epoch 29/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3226 - accuracy: 0.8788
# Epoch 30/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3155 - accuracy: 0.8812
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3240 - accuracy: 0.8813
# 0.8812999725341797
